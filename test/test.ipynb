# %%
from Bio import Entrez, SeqIO

def get_gene_and_protein_positions(rsid, transcript_location):
    # Step 1: Query rsid to get gene and protein information
    Entrez.email = "liweihao0401@gmail.com"
    handle = Entrez.efetch(db="snp", id=rsid, rettype="gb", retmode="text")
    record = SeqIO.read(handle, "genbank")
    gene_name = record.annotations["gene"]
    protein_accession = record.features[0].qualifiers["protein_id"][0]

    # Step 2: Query transcript location to get gene and protein positions
    transcript_accession = transcript_location.split(":")[0]
    position = int(transcript_location.split(":")[1])

    handle = Entrez.efetch(db="nucleotide", id=transcript_accession, rettype="gb", retmode="text")
    transcript_record = SeqIO.read(handle, "genbank")

    for feature in transcript_record.features:
        if feature.type == "CDS":
            cds_start = feature.location.start.position
            cds_end = feature.location.end.position
            if cds_start <= position <= cds_end:
                gene_position = feature.qualifiers["gene"][0]
                protein_position = position - cds_start + 1
                return gene_name, gene_position, protein_accession, protein_position

    return None

# Example usage
rsid = "rs10011796"
transcript_location = "NC_000003.12:183917980"
result = get_gene_and_protein_positions(rsid, transcript_location)

if result:
    gene_name, gene_position, protein_accession, protein_position = result
    print(f"Gene Name: {gene_name}")
    print(f"Gene Position: {gene_position}")
    print(f"Protein Accession: {protein_accession}")
    print(f"Protein Position: {protein_position}")
else:
    print("No matching information found.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e4d89f60aeba> in <module>()
#      30 rsid = "rs10011796"
#      31 transcript_location = "NC_000003.12:183917980"
# ---> 32 result = get_gene_and_protein_positions(rsid, transcript_location)
#      33
#      34 if result:
#
# <ipython-input-5-e4d89f60aeba> in get_gene_and_protein_positions(rsid, transcript_location)
#       5     Entrez.email = "liweihao0401@gmail.com"
#       6     handle = Entrez.efetch(db="snp", id=rsid, rettype="gb", retmode="text")
# ----> 7     record = SeqIO.read(handle, "genbank")
#       8     gene_name = record.annotations["gene"]
#       9     protein_accession = record.features[0].qualifiers["protein_id"][0]
#
# /home/liwh/.conda/envs/ML/lib/python3.6/site-packages/Bio/SeqIO/__init__.py in read(handle, format, alphabet)
#     654         record = next(iterator)
#     655     except StopIteration:
# --> 656         raise ValueError("No records found in handle") from None
#     657     try:
#     658         next(iterator)
#
# ValueError: No records found in handle

# %%
import requests

def get_gene_and_protein_positions(rsid, transcript_location):
    # Step 1: Query rsid to get gene and protein information
    url = f"https://rest.ensembl.org/variation/human/{rsid}"
    response = requests.get(url, headers={"Content-Type": "application/json"})
    
    if response.status_code == 200:
        data = response.json()
        print(data['mappings'][0])
        gene_name = data['mappings'][0]['gene_symbol']
        protein_id = data['mappings'][0]['protein_id']
    else:
        print(f"Error: Unable to fetch information for rsid {rsid}")
        return None

    # Step 2: Parse transcript location to get gene and protein positions
    transcript_accession, position = transcript_location.split(":")
    position = int(position)

    return gene_name, transcript_accession, position, protein_id

# Example usage
rsid = "rs1000002"
transcript_location = "NC_000003.12:183917980"
result = get_gene_and_protein_positions(rsid, transcript_location)

if result:
    gene_name, transcript_accession, position, protein_id = result
    print(f"Gene Name: {gene_name}")
    print(f"Transcript Accession: {transcript_accession}")
    print(f"Position: {position}")
    print(f"Protein ID: {protein_id}")
# Out:
# {'location': '3:183917980-183917980', 'start': 183917980, 'strand': 1, 'ancestral_allele': 'C', 'allele_string': 'C/T', 'assembly_name': 'GRCh38', 'seq_region_name': '3', 'coord_system': 'chromosome', 'end': 183917980}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-04f989cc8d70> in <module>()
#      24 rsid = "rs1000002"
#      25 transcript_location = "NC_000003.12:183917980"
# ---> 26 result = get_gene_and_protein_positions(rsid, transcript_location)
#      27
#      28 if result:
#
# <ipython-input-1-04f989cc8d70> in get_gene_and_protein_positions(rsid, transcript_location)
#       9         data = response.json()
#      10         print(data['mappings'][0])
# ---> 11         gene_name = data['mappings'][0]['gene_symbol']
#      12         protein_id = data['mappings'][0]['protein_id']
#      13     else:
#
# KeyError: 'gene_symbol'

# %%
import requests

def get_gene_and_protein_positions(rsid, transcript_location):
    # Step 1: Query rsid to get gene and protein information
    url = f"https://rest.ensembl.org/variation/human/{rsid}"
    response = requests.get(url, headers={"Content-Type": "application/json"})
    
    if response.status_code == 200:
        data = response.json()
        if 'mappings' in data and len(data['mappings']) > 0:
            transcript_accession = data['mappings'][0]['transcript_id']
            position = data['mappings'][0]['start']
        else:
            print(f"Error: Unable to fetch information for rsid {rsid}")
            return None
    else:
        print(f"Error: Unable to fetch information for rsid {rsid}")
        return None

    # Step 2: Parse transcript location to get gene and protein positions
    transcript_accession, position = transcript_location.split(":")
    position = int(position)

    return transcript_accession, position

# Example usage
rsid = "rs1000002"
transcript_location = "NC_000003.12:183917980"
result = get_gene_and_protein_positions(rsid, transcript_location)

if result:
    transcript_accession, position = result
    print(f"Transcript Accession: {transcript_accession}")
    print(f"Position: {position}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-05a98d0d8534> in <module>()
#      27 rsid = "rs1000002"
#      28 transcript_location = "NC_000003.12:183917980"
# ---> 29 result = get_gene_and_protein_positions(rsid, transcript_location)
#      30
#      31 if result:
#
# <ipython-input-2-05a98d0d8534> in get_gene_and_protein_positions(rsid, transcript_location)
#       9         data = response.json()
#      10         if 'mappings' in data and len(data['mappings']) > 0:
# ---> 11             transcript_accession = data['mappings'][0]['transcript_id']
#      12             position = data['mappings'][0]['start']
#      13         else:
#
# KeyError: 'transcript_id'

# %%
import requests

def get_gene_and_protein_positions(rsid, transcript_location):
    # Step 1: Query transcript location to get gene and protein information
    transcript_accession, position = transcript_location.split(":")
    position = int(position)

    url = f"https://rest.ensembl.org/map/human/{transcript_accession}/{position}..{position}/GRCh38"
    response = requests.get(url, headers={"Content-Type": "application/json"})
    
    if response.status_code == 200:
        data = response.json()
        if 'mappings' in data and len(data['mappings']) > 0:
            gene_name = data['mappings'][0]['external_name']
            protein_id = data['mappings'][0]['protein_id']
        else:
            print(f"Error: Unable to fetch information for rsid {rsid}")
            return None
    else:
        print(f"Error: Unable to fetch information for rsid {rsid}")
        return None

    return gene_name, transcript_accession, position, protein_id

# Example usage
rsid = "rs1000002"
transcript_location = "NC_000003.12:183917980"
result = get_gene_and_protein_positions(rsid, transcript_location)

if result:
    gene_name, transcript_accession, position, protein_id = result
    print(f"Gene Name: {gene_name}")
    print(f"Transcript Accession: {transcript_accession}")
    print(f"Position: {position}")
    print(f"Protein ID: {protein_id}")
# Out:
# Error: Unable to fetch information for rsid rs1000002

# %%
import requests
gene = '1HPV'
url = 'https://rest.uniprot.org/uniprotkb/stream?compressed=false&format=fasta&query=(reviewed:true)%20AND%20(organism_id:9606)%20AND%20' + gene
all_fastas = requests.get(url)
all_fastas
# Out:
# <Response [200]>

# %%
import requests

gene = 'ATK1'
url = 'https://rest.uniprot.org/uniprotkb/search?format=json&query=(reviewed:true)%20AND%20(organism_id:9606)%20AND%20' + gene

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    # 处理返回的JSON数据

    print(data['results'][0])
    # print(data['results'][0]['primaryAccession'])
    # for entry in data:
    #     protein_id = entry['accession']
    #     protein_name = entry['protein']['recommendedName']['fullName']
    #     print(f'Protein ID: {protein_id}, Protein Name: {protein_name}')
else:
    print(f'Error: Unable to fetch data. Status code {response.status_code}')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-0dc7706c3600> in <module>()
#      10     # 处理返回的JSON数据
#      11
# ---> 12     print(data['results'][0])
#      13     # print(data['results'][0]['primaryAccession'])
#      14     # for entry in data:
#
# IndexError: list index out of range

# %%
import pandas as pd

all_data_df = pd.read_csv('../middlefile/gdsc_all_table.tsv', sep = '\t')
symbol_list = all_data_df['gene symbol'].unique()
new_data_df = all_data_df.copy
# for i in range(len(symbol_list)):
for i in range(3):
    gene = symbol_list[i]
    url = 'https://rest.uniprot.org/uniprotkb/search?format=json&query=(reviewed:true)%20AND%20(organism_id:9606)%20AND%20' + gene
    response = requests.get(url)
    data = response.json()
    print(gene)
    print(data['results'][0]['primaryAccession'])
    new_data_df.loc[new_data_df['gene symbol'] == gene]['uniprot id'] = data['results'][0]['primaryAccession']
# Out:
# ABL1
# P00519
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-9be08fcf5cd9> in <module>()
#      12     print(gene)
#      13     print(data['results'][0]['primaryAccession'])
# ---> 14     new_data_df.loc[new_data_df['gene symbol'] == gene]['uniprot id'] = data['results'][0]['primaryAccession']
#
# AttributeError: 'function' object has no attribute 'loc'

# %%
all_data_df.head()
# Out:
#    Unnamed: 0 data source chemical name gene symbol variant uniprot id  \
# 0           0        gdsc     Nilotinib        ABL1   R608H     P00519
# 1           1        gdsc     Nilotinib        ABL1  A1045T     P00519
# 2           2        gdsc     Nilotinib        ABL1   V587M     P00519
# 3           3        gdsc     Nilotinib        ABL1   P460L     P00519
# 4           4        gdsc     Nilotinib        ABL1  G1079D     P00519
#
#         ddg
# 0  0.365149
# 1  0.620030
# 2  0.146038
# 3  0.494474
# 4  1.597725

# %%
all_data_df.loc[all_data_df['gene symbol'] == 'AKT1']
# Out:
#      Unnamed: 0 data source       chemical name gene symbol  \
# 58           58        gdsc  AKT inhibitor VIII        AKT1
# 59           59        gdsc             AT13148        AKT1
# 60           60        gdsc             AT13148        AKT1
# 61           61        gdsc             AT13148        AKT1
# 62           62        gdsc             AT13148        AKT1
# 63           63        gdsc             AT13148        AKT1
# 64           64        gdsc             AT13148        AKT1
# 65           65        gdsc             AT13148        AKT1
# 66           66        gdsc             AT13148        AKT1
# 67           67        gdsc             AT13148        AKT1
# 68           68        gdsc             AT13148        AKT1
# 69           69        gdsc             AT13148        AKT1
# 70           70        gdsc             AT13148        AKT1
# 71           71        gdsc             AT13148        AKT1
# 72           72        gdsc             AT13148        AKT1
# 73           73        gdsc              AT7867        AKT1
# 74           74        gdsc              AT7867        AKT1
# 75           75        gdsc              AT7867        AKT1
# 76           76        gdsc              AT7867        AKT1
# 77           77        gdsc              AT7867        AKT1
# 78           78        gdsc              AT7867        AKT1
# 79           79        gdsc              AT7867        AKT1
# 80           80        gdsc              AT7867        AKT1
# 81           81        gdsc              AT7867        AKT1
# 82           82        gdsc              AT7867        AKT1
# 83           83        gdsc              AT7867        AKT1
# 84           84        gdsc              AT7867        AKT1
# 85           85        gdsc              AT7867        AKT1
# 86           86        gdsc              AT7867        AKT1
# 87           87        gdsc              AT7867        AKT1
# 88           88        gdsc              AT7867        AKT1
# 89           89        gdsc        Capivasertib        AKT1
# 90           90        gdsc        Capivasertib        AKT1
# 91           91        gdsc        Capivasertib        AKT1
# 92           92        gdsc        Capivasertib        AKT1
# 93           93        gdsc        Capivasertib        AKT1
# 94           94        gdsc        Capivasertib        AKT1
# 95           95        gdsc        Capivasertib        AKT1
# 96           96        gdsc        Capivasertib        AKT1
# 97           97        gdsc        Capivasertib        AKT1
# 98           98        gdsc        Capivasertib        AKT1
# 99           99        gdsc        Capivasertib        AKT1
# 100         100        gdsc        Capivasertib        AKT1
# 101         101        gdsc        Capivasertib        AKT1
# 102         102        gdsc        Capivasertib        AKT1
# 103         103        gdsc        Capivasertib        AKT1
# 104         104        gdsc           GSK690693        AKT1
# 105         105        gdsc             MK-2206        AKT1
# 106         106        gdsc             MK-2206        AKT1
# 107         107        gdsc          Uprosertib        AKT1
#
#                variant uniprot id       ddg
# 58          A230T+Q59*     Q96B36 -0.655527
# 59               R406H     Q96B36 -0.811391
# 60                Q59*     Q96B36  0.500563
# 61               S266L     Q96B36  0.494086
# 62               Y272C     Q96B36 -0.057076
# 63                R86H     Q96B36  0.220549
# 64                E17K     Q96B36  0.971729
# 65               R200H     Q96B36 -0.911317
# 66               G478S     Q96B36  0.566527
# 67           E49K+E17K     Q96B36 -0.033916
# 68                 D3N     Q96B36  0.368037
# 69               R346C     Q96B36  0.259190
# 70   G311D+K307N+Y215H     Q96B36 -0.187630
# 71               Q104H     Q96B36  2.110962
# 72               V337M     Q96B36  0.379864
# 73               R406H     Q96B36  0.133493
# 74                Q59*     Q96B36 -0.436206
# 75               S266L     Q96B36  1.087629
# 76               Y272C     Q96B36  0.748588
# 77                R86H     Q96B36  0.158217
# 78                E17K     Q96B36 -0.308907
# 79               R200H     Q96B36 -0.838290
# 80                I75M     Q96B36  0.301774
# 81           E49K+E17K     Q96B36  0.392453
# 82                 D3N     Q96B36  0.597654
# 83               R346C     Q96B36  0.586857
# 84   G311D+K307N+Y215H     Q96B36  0.473354
# 85               Q104H     Q96B36  1.694066
# 86          A230T+Q59*     Q96B36 -0.026680
# 87               V337M     Q96B36 -0.129403
# 88                R86H     Q96B36  0.051619
# 89               R406H     Q96B36 -1.104249
# 90                Q59*     Q96B36  0.720858
# 91               S266L     Q96B36 -0.056350
# 92               Y272C     Q96B36 -0.463253
# 93                R86H     Q96B36 -1.434665
# 94                E17K     Q96B36  0.189023
# 95               R200H     Q96B36 -0.464057
# 96                I75M     Q96B36 -0.307551
# 97               G478S     Q96B36  1.053708
# 98           E49K+E17K     Q96B36 -0.265139
# 99                 D3N     Q96B36 -1.445702
# 100              R346C     Q96B36 -1.179938
# 101  G311D+K307N+Y215H     Q96B36 -2.214254
# 102              Q104H     Q96B36  2.395637
# 103               R86H     Q96B36  0.645487
# 104         A230T+Q59*     Q96B36 -1.320627
# 105               R86H     Q96B36 -1.239870
# 106         A230T+Q59*     Q96B36 -0.050766
# 107         A230T+Q59*     Q96B36 -0.594811
